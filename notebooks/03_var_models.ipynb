# %% [markdown]
# # 03 — VaR & Expected Shortfall
#
# **Goal:** calculate Value-at-Risk via three methodologies, plus Expected Shortfall, at 95% and 99% confidence.
#
# **Plan:**
# 1. Historical Simulation VaR
# 2. Parametric VaR (normal vs. Student-t — informed by the skew/kurtosis findings from notebook 01)
# 3. Monte Carlo VaR (10,000+ simulated paths)
# 4. Expected Shortfall at each confidence level
# 5. Summary table + chart comparing all methods

# %%
import sys
sys.path.append('..')

import pandas as pd
from src.var import historical_var, parametric_var, monte_carlo_var, expected_shortfall, var_summary

port_returns = pd.read_csv('../data/portfolio_returns.csv', index_col=0, parse_dates=True).iloc[:, 0]

# %% [markdown]
# ## VaR summary table
#
# Uses `var_summary()` from `src/var.py` — see that module for each method's assumptions.

# %%
summary = var_summary(port_returns, confidence_levels=[0.95, 0.99])
summary

# %% [markdown]
# ## Visualise VaR vs. the realised loss distribution
#
# *(Plot the return histogram with each VaR threshold overlaid as a vertical line — a strong chart for the risk report.)*

# %%
# TODO: histogram of port_returns with VaR thresholds overlaid

# %% [markdown]
# ---
#
# **Next notebook:** `04_backtesting.ipynb` — Kupiec and Christoffersen tests on the VaR series above.
